# %%
from music21 import *
def play(stream):
    midi.realtime.StreamPlayer(stream).play()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-5025b982a8cd> in <module>
# ----> 1 from music21 import *
#       2 def play(stream):
#       3     midi.realtime.StreamPlayer(stream).play()
#
# ModuleNotFoundError: No module named 'music21'

# %% [markdown]
# ## Nardis

# %%
nardis = stream.Stream()
nardis.append(meter.TimeSignature('4/4'))
#Standard voicings here too
Emin7 = chord.Chord('E G B D', quarterLength = 4)
Fmaj7 = chord.Chord('F A C E', quarterLength = 4)
B7 = chord.Chord('B D# F# A', quarterLength = 4)
Cmaj7 = chord.Chord('C E G B', quarterLength = 4)
Amin7 = chord.Chord('A C E G', quarterLength = 4)
Dmin7 = chord.Chord('D F A C', quarterLength = 4)
G7 = chord.Chord('G B D F', quarterLength = 4)
Emaj7= chord.Chord('E G# B D#', quarterLength = 4)

nardisA = [Emin7, Fmaj7, B7, Cmaj7, Amin7, Fmaj7, Emaj7, Emin7]
nardisB = [Amin7, Fmaj7, Amin7, Fmaj7, Dmin7, G7, Cmaj7, Fmaj7]
nardisTot = nardisA + nardisA + nardisB + nardisA


#This snippet is simply for demonstrational purposes. The real work will use {@var NardisA} and {@var NardisB}.
for i in range(0, 32):
    m=stream.Measure(i)
    m.append(nardisTot[i])
    nardis.append(m)

nardis.show()
play(nardis)
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ## Autumn Leaves

# %%
leaves = stream.Stream()
leaves.append(meter.TimeSignature('4/4'))
leavesC = []
#We're choosing the standard voicing for now, we will change it before the submission

Cmin7=chord.Chord('C Eb G Bb')
leavesC.append(Cmin7)
F7 = chord.Chord('F A C Eb')
leavesC.append(F7)
BbMaj7 = chord.Chord('Bb D F A')
leavesC.append(BbMaj7)
for ch in leavesC:
    leaves.append(ch)
    
leaves.show()
play(leaves)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-59e0c0cc1aeb> in <module>
# ----> 1 leaves = stream.Stream()
#       2 leaves.append(meter.TimeSignature('4/4'))
#       3 leavesC = []
#       4 #We're choosing the standard voicing for now, we will change it before the submission
#       5
#
# NameError: name 'stream' is not defined
